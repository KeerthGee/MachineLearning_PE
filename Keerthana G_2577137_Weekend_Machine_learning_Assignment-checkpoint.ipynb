# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('cars_train.xlsx')
data
# Out:
#      symboling  normalized.losses        make fuel.type aspiration  \
# 0            1              129.0       mazda       gas        std
# 1            1              125.0  mitsubishi       gas        std
# 2            3              150.0       mazda       gas        std
# 3            3              194.0      nissan       gas        std
# 4            0               85.0       honda       gas        std
# ..         ...                ...         ...       ...        ...
# 157          0                NaN      peugot       gas        std
# 158          3              145.0       dodge       gas      turbo
# 159          3              194.0      nissan       gas        std
# 160          0               85.0       honda       gas        std
# 161          2               83.0      subaru       gas        std
#
#     num.of.doors body.style drive.wheels engine.location  wheel.base  ...  \
# 0            two  hatchback          fwd           front        98.8  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_make = LabelEncoder()
le_fuel_type = LabelEncoder()
le_aspiration= LabelEncoder()
le_num_of_doors= LabelEncoder()
le_body_style= LabelEncoder()
le_drive_wheels= LabelEncoder()
le_engine_location= LabelEncoder()
le_fuel_system= LabelEncoder()
le_num_of_cylinders = LabelEncoder()

# %%
data['make'] = le_make.fit_transform(data['make'])
data['fuel.type'] = le_fuel_type.fit_transform(data['fuel.type'])
data['aspiration'] = le_aspiration.fit_transform(data['aspiration'])
data['num.of.doors'] = le_num_of_doors.fit_transform(data['num.of.doors'])
data['body.style'] = le_body_style.fit_transform(data['body.style'])
data['drive.wheels'] = le_drive_wheels.fit_transform(data['drive.wheels'])
data['engine.location'] = le_engine_location.fit_transform(data['engine.location'])
data['fuel.system'] = le_fuel_system.fit_transform(data['fuel.system'])
data['num.of.cylinders'] = le_num_of_cylinders.fit_transform(data['num.of.cylinders'])
data.head(20)
# Out:
#     symboling  normalized.losses  make  fuel.type  aspiration  num.of.doors  \
# 0           1              129.0     8          1           0             1
# 1           1              125.0    10          1           0             0
# 2           3              150.0     8          1           0             1
# 3           3              194.0    11          1           0             2
# 4           0               85.0     5          1           0             0
# 5           2               83.0    17          1           0             1
# 6           2                NaN    15          1           0             1
# 7           3              186.0    14          1           0             1
# 8           3              150.0    16          1           0             1
# 9           0                NaN     8          0           0             0
# 10          0                NaN     1          1           1             1
# ...

# %%
data_1=data.drop(['Car_Price','engine.type'],axis='columns')
data_1.head(50)
# Out:
#     symboling  normalized.losses  make  fuel.type  aspiration  num.of.doors  \
# 0           1              129.0     8          1           0             1
# 1           1              125.0    10          1           0             0
# 2           3              150.0     8          1           0             1
# 3           3              194.0    11          1           0             2
# 4           0               85.0     5          1           0             0
# 5           2               83.0    17          1           0             1
# 6           2                NaN    15          1           0             1
# 7           3              186.0    14          1           0             1
# 8           3              150.0    16          1           0             1
# 9           0                NaN     8          0           0             0
# 10          0                NaN     1          1           1             1
# ...

# %%
target = data['Car_Price']
target
# Out:
# 0      10595.0
# 1       8189.0
# 2      13645.0
# 3      17199.0
# 4      12945.0
#         ...
# 157    16695.0
# 158    12964.0
# 159    17199.0
# 160    12945.0
# 161     7603.0
# Name: Car_Price, Length: 162, dtype: float64

# %%
data_1= data_1.fillna(method='bfill')
data_1.isna().sum()
# Out:
# symboling            0
# normalized.losses    0
# make                 0
# fuel.type            0
# aspiration           0
# num.of.doors         0
# body.style           0
# drive.wheels         0
# engine.location      0
# wheel.base           0
# length               0
# width                0
# height               0
# curb.weight          0
# num.of.cylinders     0
# engine.size          0
# fuel.system          0
# bore                 0
# stroke               0
# compression.ratio    0
# horsepower           0
# peak.rpm             0
# city.mpg             0
# highway.mpg          0
# dtype: int64

# %%
target= target.fillna(method='bfill')
target.isna().sum()
# Out:
# 0

# %% [markdown]
# # Assign X and Y

# %%
data_1.head(2)
# Out:
#    symboling  normalized.losses  make  fuel.type  aspiration  num.of.doors  \
# 0          1              129.0     8          1           0             1
# 1          1              125.0    10          1           0             0
#
#    body.style  drive.wheels  engine.location  wheel.base  ...  \
# 0           2             1                0        98.8  ...
# 1           3             1                0        96.3  ...
#
#    num.of.cylinders  engine.size  fuel.system  bore  stroke  \
# 0                 2          122            1  3.39    3.39
# 1                 2          122            1  3.35    3.46
#
#    compression.ratio  horsepower  peak.rpm  city.mpg  highway.mpg
# 0                8.6        84.0    4800.0        26           32
# 1                8.5        88.0    5000.0        25           32
#
# [2 rows x 24 columns]

# %%
x=data_1
y=target

# %%
x
# Out:
#      symboling  normalized.losses  make  fuel.type  aspiration  num.of.doors  \
# 0            1              129.0     8          1           0             1
# 1            1              125.0    10          1           0             0
# 2            3              150.0     8          1           0             1
# 3            3              194.0    11          1           0             2
# 4            0               85.0     5          1           0             0
# ..         ...                ...   ...        ...         ...           ...
# 157          0              145.0    12          1           0             0
# 158          3              145.0     4          1           1             1
# 159          3              194.0    11          1           0             2
# 160          0               85.0     5          1           0             0
# 161          2               83.0    17          1           0             1
#
# ...

# %%
y
# Out:
# 0      10595.0
# 1       8189.0
# 2      13645.0
# 3      17199.0
# 4      12945.0
#         ...
# 157    16695.0
# 158    12964.0
# 159    17199.0
# 160    12945.0
# 161     7603.0
# Name: Car_Price, Length: 162, dtype: float64

# %%
sns.countplot(target)
# Out:
# <Axes: ylabel='count'>

# %%
data.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10128\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    symboling  normalized.losses      make  fuel.type  \
# symboling           1.000000           0.538664 -0.077937   0.181603
# normalized.losses   0.538664           1.000000 -0.220797   0.079198
# make               -0.077937          -0.220797  1.000000  -0.050428
# fuel.type           0.181603           0.079198 -0.050428   1.000000
# aspiration         -0.022238           0.038268  0.021969  -0.355113
# num.of.doors        0.544503           0.343809 -0.027833   0.033825
# body.style         -0.611864          -0.278302  0.042936  -0.162951
# drive.wheels       -0.048645           0.428111 -0.009837  -0.159604
# ...

# %% [markdown]
# # Split the data for training and testing

# %%
import sklearn

from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
data_1.shape
# Out:
# (162, 24)

# %%
xtrain.shape
# Out:
# (129, 24)

# %%
xtest
# Out:
#      symboling  normalized.losses  make  fuel.type  aspiration  num.of.doors  \
# 12           0              104.0    19          1           0             0
# 3            3              194.0    11          1           0             2
# 138          0              161.0    12          0           1             0
# 6            2              186.0    15          1           0             1
# 137          0              145.0     7          1           0             0
# 84           3              197.0    18          1           0             1
# 87          -1               93.0     9          0           1             0
# 122          3              153.0    10          1           1             1
# 29          -1               93.0     9          0           1             0
# 139          2              161.0    10          1           0             2
# 44           2              137.0     5          1           0             1
# ...

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge 
from sklearn.linear_model import Lasso

# %%
#build Base regression model
base_reg=LinearRegression()
print('***********Base Regression************')
print()
print('Training Started....\n')
base_reg.fit(xtrain, ytrain)
print()
base_pred=base_reg.predict(xtest)

 #Performance Metrics

from sklearn.metrics import r2_score

print('Base Train_score: \t', base_reg.score (xtrain, ytrain))
print()
print('Base Test_score: \t', base_reg.score (xtest,ytest))
print()
print('R-Square: \t', r2_score (ytest, base_pred))
# Out:
# ***********Base Regression************
#
# Training Started....
#
#
# Base Train_score: 	 0.8694041665048274
#
# Base Test_score: 	 0.8211950531451335
#
# R-Square: 	 0.8211950531451335

# %%
#Build Ridge model
print('******************Ridge Regression Model***************')
rr=Ridge(alpha=0.01)
rr.fit(xtrain,ytrain)
rr_pred=rr.predict(xtest)
print('Ridge Train_score:\t',rr.score(xtrain,ytrain))
print()
print('Ridge Test Score:\t',rr.score(xtest,ytest))
print()
print('Ridge R-Square:\t',r2_score(ytest,rr_pred))
# Out:
# ******************Ridge Regression Model***************
# Ridge Train_score:	 0.8694035774572074
#
# Ridge Test Score:	 0.821236761169577
#
# Ridge R-Square:	 0.821236761169577

# %%
#Build Ridge model with alpha =100
print('************Ridge Regression Model*************')
rr100=Ridge(alpha=100)
rr100.fit(xtrain,ytrain)
rr100_pred=rr100.predict(xtest)
print('Ridge Train_score:\t',rr100.score(xtrain,ytrain))
print()
print('Ridge Test score:\t',rr100.score(xtest,ytest))
print()
print('Ridge R-Square:\t',r2_score(ytest,rr100_pred))
# Out:
# ************Ridge Regression Model*************
# Ridge Train_score:	 0.8285325175946361
#
# Ridge Test score:	 0.8068087950555868
#
# Ridge R-Square:	 0.8068087950555868

# %%
base_reg.coef_
# Out:
# array([ 7.64256279e+01, -7.53816090e+00, -2.40849135e+02,  2.40345438e+03,
#         1.00189249e+03, -8.53730144e+02, -1.09117408e+03,  2.53843859e+03,
#         3.01194200e+03, -1.04792866e+02,  5.10790345e+01, -2.10142971e+01,
#         5.36588906e+02,  1.37833342e+00,  2.71147932e+00,  1.13328970e+02,
#         9.64032955e+01,  9.31836464e+02, -2.69089935e+03,  3.56764595e+02,
#         2.70299111e+00,  1.55828143e+00, -8.72363004e+01,  4.26515648e+01])

# %%
rr.coef_
# Out:
# array([ 7.66547022e+01, -7.58937560e+00, -2.40527516e+02,  2.21929526e+03,
#         9.86046422e+02, -8.52172313e+02, -1.09030851e+03,  2.53979697e+03,
#         3.00573654e+03, -1.04998539e+02,  5.11554437e+01, -2.03851399e+01,
#         5.36211295e+02,  1.37514150e+00,  3.75180316e+00,  1.13356631e+02,
#         9.58589356e+01,  9.27272775e+02, -2.69485365e+03,  3.43716513e+02,
#         2.77015041e+00,  1.56373348e+00, -8.69961874e+01,  4.27470590e+01])

# %%
rr100.coef_
# Out:
# array([ 115.06478178,   -8.58680411, -149.82068483,   -2.3327202 ,
#         -35.12688177, -166.24208798, -407.68002814,  495.47242392,
#         278.68742783,    6.43755704,   13.95354462, -209.25170065,
#         346.36070019,    2.76475518,   17.17684338,  115.14221518,
#          87.0161085 ,  103.47931251, -341.35048168,  206.06153428,
#          13.35869817,    2.09364725, -185.28930667,  107.60649964])

# %% [markdown]
# # Lasso Regression Boston dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge 
from sklearn.linear_model import Lasso

# %%
#Build Ridge model
print('******************Lasso Regression Model***************')
lr=Lasso(alpha=0.01)
lr.fit(xtrain,ytrain)
lr_pred=lr.predict(xtest)
print('Lasso Train_score:\t',lr.score(xtrain,ytrain))
print()
print('Lasso Test Score:\t',lr.score(xtest,ytest))
print()
print('Lasso R-Square:\t',r2_score(ytest,lr_pred))
# Out:
# ******************Lasso Regression Model***************
# Lasso Train_score:	 0.8694041639369736
#
# Lasso Test Score:	 0.821197575208442
#
# Lasso R-Square:	 0.821197575208442

# %%
#Build Ridge model
print('******************Lasso Regression Model***************')
lr=Lasso(alpha=0.00001)
lr.fit(xtrain,ytrain)
lr_pred=lr.predict(xtest)
print('Lasso Train_score:\t',lr.score(xtrain,ytrain))
print()
print('Lasso Test Score:\t',lr.score(xtest,ytest))
print()
print('Lasso R-Square:\t',r2_score(ytest,lr_pred))
# Out:
# ******************Lasso Regression Model***************
# Lasso Train_score:	 0.8694041665048078
#
# Lasso Test Score:	 0.821195060626209
#
# Lasso R-Square:	 0.821195060626209
# C:\Anaconda\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.860e+08, tolerance: 7.473e+05
#   model = cd_fast.enet_coordinate_descent(
